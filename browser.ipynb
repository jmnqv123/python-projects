# %%
# Install libraries (only first time)
# !pip install beautifulsoup4 requests ipywidgets

import requests
from bs4 import BeautifulSoup
import ipywidgets as widgets
from IPython.display import display, HTML, clear_output

# Function to fetch and display web content
def browse(url):
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')

        # Clear previous outputs
        clear_output(wait=True)

        # Display website title and some content
        title = soup.title.string if soup.title else "No Title Found"
        print(f"Website Title: {title}\n")

        # Display a preview of the text content
        paragraphs = soup.find_all('p')
        for p in paragraphs[:5]:  # Show first 5 paragraphs
            print(p.get_text())

        # Show the page link again and input for next browsing
        display(ui)

    except Exception as e:
        print(f"Error: {e}")
        display(ui)

# Text input widget
url_text = widgets.Text(
    value='https://example.com',
    placeholder='Type website URL here (with https://)',
    description='URL:',
    disabled=False
)

# Button widget
go_button = widgets.Button(
    description='Browse!',
    disabled=False,
    button_style='success'
)

# On button click
def on_button_clicked(b):
    browse(url_text.value)

# Button click event
go_button.on_click(on_button_clicked)

# Group widgets
ui = widgets.VBox([url_text, go_button])

# Display interface
display(ui)
